# %% [markdown]
# <a href="https://colab.research.google.com/github/guilmoreira/mercado_financeiro/blob/main/bitcoin_drawdown.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install investpy -q
#!pip install plotly
# !pip install quandl

# %%
import datetime
import investpy as inv
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
from plotly.subplots import make_subplots

#PERIODO ESTUDADO - apartir de 2019
inicio_periodo="2010-01-01"
final_periodo="2022-06-20"

#CONVERTENDO FORMATO DE DATA
inicio_ft=datetime.datetime.strptime(inicio_periodo,'%Y-%m-%d').strftime('%d/%m/%Y')
final_ft=datetime.datetime.strptime(final_periodo,'%Y-%m-%d').strftime('%d/%m/%Y')

#BTC - DADOS
bitcoin=inv.get_crypto_historical_data(crypto = 'Bitcoin', from_date= inicio_ft, to_date=final_ft)
df=pd.DataFrame(bitcoin)
btc=bitcoin['Close']

#BTC - DRAWDOWN
db['Retorno BTC']=db['BTC'].pct_change().iloc[1:]
retornos=db['Retorno BTC']
wea=(1000*(1+retornos).cumprod())
picos=wea.cummax()
db['Drawdown']=(wea-picos)/picos
db=db.dropna()
drawdown=db['Drawdown']

# %%
px.line(btc,y=btc,labels={'y':'BTC Price ($)'}, template='plotly_dark',width=1500, height=500)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.area(drawdown,y=db['Drawdown'],labels={'y':'Drawdown (%)'}, template='plotly_dark',width=1500, height=500)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
max_drawdown=(db['Drawdown'].min())*-100

# %%
print(int(max_drawdown))
# Out:
# 93
